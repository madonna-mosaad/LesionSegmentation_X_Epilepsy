# %% [markdown]
# # Imports

# %%
import numpy as np 
import pandas as pd 
import os
import shutil

# !pip install nnunetv2

# %% [markdown]
# # Set the environment variables

# %%
# Path to your uploaded dataset
base = "/kaggle/input/pre-processed-data"

# Tell nnU-Net where to find data and where to save results
os.environ["nnUNet_raw"] = f"{base}/nnUNet_raw"
os.environ["nnUNet_preprocessed"] = f"{base}/nnUNet_preprocessed"
os.environ["nnUNet_results"] = "/kaggle/working/nnUNet_results"

# Verify
# !echo "Raw data: $nnUNet_raw"
# !echo "Preprocessed data: $nnUNet_preprocessed"
# !echo "Results: $nnUNet_results"

# %% [markdown]
# # Disable torch.compile for compatibility with older GPUs

# %%
os.environ["NNUNET_USE_TORCH_COMPILE"] = "0"   # <- main fix
os.environ["TORCH_COMPILE_DISABLE"] = "1"       # <- extra safety
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import torch._dynamo
torch._dynamo.config.suppress_errors = True

print("Torch Compile disabled. Ready to train nnU-Net safely on Tesla P100 ✅")

# %% [markdown]
# # Training 3D model

# %%
# training 3d full resolution all folds

# !nnUNetv2_train 1 3d_fullres 0
# !nnUNetv2_train 1 3d_fullres 1
# !nnUNetv2_train 1 3d_fullres 2
# !nnUNetv2_train 1 3d_fullres 3
# !nnUNetv2_train 1 3d_fullres 4
