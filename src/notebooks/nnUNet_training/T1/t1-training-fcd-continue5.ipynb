# %%
# !pip install nnunetv2 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/211.5 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 kB 7.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/363.4 MB 126.0 MB/s eta 0:00:03
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/363.4 MB 203.2 MB/s eta 0:00:02
#    ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.4/363.4 MB 222.8 MB/s eta 0:00:02
# ...

# %%
import os

# Define base paths
base_input = "/kaggle/input/t1-training-fcd-dataset5"
base_working = "/kaggle/working"

# Define nnU-Net paths inside working directory
nnunet_raw = os.path.join(base_working, "nnUNet_raw")
nnunet_preprocessed = os.path.join(base_working, "nnUNet_preprocessed")
nnunet_results = os.path.join(base_working, "nnUNet_results")

# Create empty raw folder (even if not used)
os.makedirs(nnunet_raw, exist_ok=True)
os.makedirs(nnunet_preprocessed, exist_ok=True)
os.makedirs(nnunet_results, exist_ok=True)

# Set environment variables
os.environ["nnUNet_raw"] = nnunet_raw
os.environ["nnUNet_preprocessed"] = nnunet_preprocessed
os.environ["nnUNet_results"] = nnunet_results

# For torch on Kaggle GPU (P100)
os.environ["TORCH_COMPILE_DISABLE"] = "1"

print("✅ Environment variables set")
# Out:
# ✅ Environment variables set

# %%
# !cp -r /kaggle/input/t1-training-fcd-dataset5/nnUNet_preprocessed/* /kaggle/working/nnUNet_preprocessed/
# !cp -r /kaggle/input/t1-training-fcd-dataset5/nnUNet_results/* /kaggle/working/nnUNet_results/

# %%
# !nnUNetv2_train Dataset001_BonnFCD 3d_fullres 0 --c
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
# 2025-10-23 08:56:25.347430: Using torch.compile...
# 2025-10-23 08:56:27.862572: do_dummy_2d_data_aug: False
# 2025-10-23 08:56:27.863178: Using splits from existing split file: /kaggle/working/nnUNet_preprocessed/Dataset001_BonnFCD/splits_final.json
# ...
